# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import numpy as np

# %%
new_model = tf.saved_model.load('MNIST_model')

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Agrega una dimension de canales
x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
test_out = new_model(x_test)
print(test_out)
# Out:
# tf.Tensor(
# [[4.40684772e-12 1.05593493e-18 2.72022196e-11 ... 1.00000000e+00
#   2.29015529e-10 3.66601333e-11]
#  [2.01627597e-22 4.99660155e-13 1.00000000e+00 ... 2.90494104e-24
#   1.87995757e-21 3.74977932e-23]
#  [7.90484106e-13 1.00000000e+00 1.81708482e-10 ... 8.91226259e-10
#   2.40884579e-09 5.40831594e-13]
#  ...
#  [1.36050021e-25 1.97556269e-18 1.67960515e-22 ... 1.76990755e-10
#   7.29507058e-13 4.55399173e-12]
#  [1.05993324e-20 3.44909586e-25 4.73550833e-28 ... 1.52348526e-24
#   5.97766114e-10 3.35549499e-20]
#  [1.51312404e-16 7.46874054e-16 3.32179578e-20 ... 7.14068981e-29
#   5.24745844e-18 4.57579254e-20]], shape=(10000, 10), dtype=float32)

# %%
new_model(x_test[:2])
# Out:
# <tf.Tensor: shape=(2, 10), dtype=float32, numpy=
# array([[4.4068226e-12, 1.0559269e-18, 2.7202116e-11, 2.0377854e-13,
#         1.6059549e-19, 1.3459801e-16, 7.8577797e-23, 1.0000000e+00,
#         2.2901422e-10, 3.6659994e-11],
#        [2.0162683e-22, 4.9965544e-13, 1.0000000e+00, 2.6262250e-19,
#         7.0660145e-28, 1.0543990e-30, 4.8804237e-22, 2.9049189e-24,
#         1.8799432e-21, 3.7497506e-23]], dtype=float32)>

# %%
np.matrix(new_model(x_test[:2])).argmax(1)
# Out:
# matrix([[7],
#         [2]], dtype=int64)

# %%
y_test[:2]
# Out:
# array([7, 2], dtype=uint8)

# %%
result = np.matrix(test_out).argmax(1).reshape(y_test.shape) - y_test
result
# Out:
# matrix([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
# DRAW SOME CLASSIFIED SAMPLES
st=300
for i in range(10):
    print('Predicted = ' + str(np.argmax(test_out[st+i,:])) + ' ::  Real = ' + str(y_test[st+i]))
    plt.imshow(x_test[st+i,:,:,0])
    plt.show()
# Out:
# Predicted = 4 ::  Real = 4
# Predicted = 7 ::  Real = 7
# Predicted = 1 ::  Real = 1
# Predicted = 2 ::  Real = 2
# Predicted = 4 ::  Real = 4
# Predicted = 0 ::  Real = 0
# Predicted = 2 ::  Real = 2
# Predicted = 7 ::  Real = 7
# Predicted = 4 ::  Real = 4
# Predicted = 3 ::  Real = 3

# %%
# DRAW INCORRECTLY CLASSIFIED SAMPLES
idres = np.where(result>0)[1] # find de id of the elments classified incorrectly
print('Wrong samples : ' +  str(idres.shape[0]))
for i in idres:
    print('Predicted = ' + str(np.argmax(test_out[i,:])) + ' ::  Real = ' + str(y_test[i]))
    plt.imshow(x_test[i,:,:,0])
    plt.show()
# Out:
# Wrong samples : 78
# Predicted = 8 ::  Real = 5
# Predicted = 7 ::  Real = 2
# Predicted = 9 ::  Real = 4
# Predicted = 8 ::  Real = 1
# Predicted = 6 ::  Real = 0
# Predicted = 8 ::  Real = 5
# Predicted = 9 ::  Real = 4
# Predicted = 5 ::  Real = 3
# Predicted = 6 ::  Real = 1
# Predicted = 8 ::  Real = 6
# Predicted = 6 ::  Real = 4
# Predicted = 8 ::  Real = 7
# Predicted = 8 ::  Real = 6
# Predicted = 4 ::  Real = 2
# Predicted = 9 ::  Real = 4
# Predicted = 9 ::  Real = 7
# Predicted = 5 ::  Real = 1
# Predicted = 6 ::  Real = 4
# Predicted = 6 ::  Real = 2
# Predicted = 6 ::  Real = 0
# Predicted = 6 ::  Real = 5
# Predicted = 8 ::  Real = 5
# Predicted = 8 ::  Real = 2
# Predicted = 9 ::  Real = 4
# Predicted = 9 ::  Real = 3
# Predicted = 9 ::  Real = 4
# Predicted = 8 ::  Real = 5
# Predicted = 6 ::  Real = 1
# Predicted = 9 ::  Real = 4
# Predicted = 4 ::  Real = 2
# Predicted = 5 ::  Real = 3
# Predicted = 8 ::  Real = 6
# Predicted = 9 ::  Real = 8
# Predicted = 8 ::  Real = 2
# Predicted = 6 ::  Real = 1
# Predicted = 9 ::  Real = 8
# Predicted = 8 ::  Real = 7
# Predicted = 4 ::  Real = 0
# Predicted = 8 ::  Real = 6
# Predicted = 6 ::  Real = 5
# Predicted = 9 ::  Real = 7
# Predicted = 2 ::  Real = 0
# Predicted = 7 ::  Real = 2
# Predicted = 9 ::  Real = 7
# Predicted = 7 ::  Real = 1
# Predicted = 7 ::  Real = 2
# Predicted = 7 ::  Real = 2
# Predicted = 9 ::  Real = 7
# Predicted = 9 ::  Real = 8
# Predicted = 9 ::  Real = 7
# Predicted = 5 ::  Real = 3
# Predicted = 9 ::  Real = 4
# Predicted = 8 ::  Real = 7
# Predicted = 6 ::  Real = 1
# Predicted = 8 ::  Real = 2
# Predicted = 9 ::  Real = 7
# Predicted = 9 ::  Real = 4
# Predicted = 8 ::  Real = 3
# Predicted = 6 ::  Real = 0
# Predicted = 9 ::  Real = 8
# Predicted = 2 ::  Real = 0
# Predicted = 7 ::  Real = 0
# Predicted = 8 ::  Real = 0
# Predicted = 9 ::  Real = 8
# Predicted = 8 ::  Real = 5
# Predicted = 8 ::  Real = 5
# Predicted = 8 ::  Real = 2
# Predicted = 9 ::  Real = 3
# Predicted = 8 ::  Real = 3
# Predicted = 6 ::  Real = 0
# Predicted = 9 ::  Real = 4
# Predicted = 8 ::  Real = 1
# Predicted = 8 ::  Real = 0
# Predicted = 7 ::  Real = 2
# Predicted = 6 ::  Real = 5
# Predicted = 9 ::  Real = 4
# Predicted = 3 ::  Real = 2
# Predicted = 7 ::  Real = 2

# %%
new_model.layers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-077b5aa0a1ba> in <module>
# ----> 1 new_model.layers
#
# AttributeError: '_UserObject' object has no attribute 'layers'

# %%
#new_model(x_test)
aa = x_test[:2,:,:,:]
new_model(aa)
# Out:
# <tf.Tensor: id=882, shape=(2, 10), dtype=float32, numpy=
# array([[3.2173212e-14, 5.9840008e-11, 5.1263815e-10, 5.0863669e-08,
#         2.2681284e-14, 9.8547483e-13, 4.7392370e-18, 1.0000000e+00,
#         4.4498759e-11, 5.7547822e-10],
#        [1.4535206e-16, 7.9658974e-13, 1.0000000e+00, 3.5879318e-16,
#         8.5815950e-23, 2.0767837e-21, 2.6708953e-16, 2.3537778e-23,
#         2.6264694e-16, 7.5596364e-23]], dtype=float32)>
