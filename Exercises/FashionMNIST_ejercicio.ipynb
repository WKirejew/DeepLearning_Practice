# %%
import tensorflow as tf

from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras import Model

import matplotlib.pyplot as plt
import numpy as np


from tensorflow import keras


print(tf.__version__)
# Out:
# 2.4.1

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
print(train_images.shape, train_labels.shape)
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# Out:
# (60000, 28, 28) (60000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
l1=10
for i in range(l1):
  plt.figure(figsize=(20,10))
  plt.subplot(151)
  plt.imshow(train_images[i,:,:])
  plt.title(class_names[train_labels[i]])
  plt.subplot(152)
  plt.imshow(train_images[i+l1,:,:])
  plt.title(class_names[train_labels[i+l1]])
  plt.subplot(153)
  plt.imshow(train_images[i+2*l1,:,:])
  plt.title(class_names[train_labels[i+2*l1]])
  plt.subplot(154)
  plt.imshow(train_images[i+3*l1,:,:])
  plt.title(class_names[train_labels[i+3*l1]])
  plt.subplot(155)
  plt.imshow(train_images[i+4*l1,:,:])
  plt.title(class_names[train_labels[i+4*l1]])
  plt.show()

# %%
# Agrega una dimension de canales
x_train = train_images[..., tf.newaxis] #.reshape((x_train.shape[0],784,1))
x_test = test_images[..., tf.newaxis]

# %%
# Exercise

1) Define and Train a network for Fashion MNIST classification.

2) Check the importance of the number of training data by training the model with {60K, 10K, 1K, 300} images.
